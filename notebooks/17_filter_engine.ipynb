# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.screener.engine import load_screener_data

DB_PATH = PROJECT_ROOT / "data" / "nifty100.db"

df = load_screener_data(DB_PATH)

df.head()
# Out:
#   company_id      company_name    year broad_sector  return_on_equity_pct  \
# 0        ABB  Abbott India Ltd  2012.0  Industrials             22.411128
# 1        ABB  Abbott India Ltd  2014.0  Industrials             25.126904
# 2        ABB  Abbott India Ltd  2015.0  Industrials             24.439701
# 3        ABB  Abbott India Ltd  2016.0  Industrials             21.338912
# 4        ABB  Abbott India Ltd  2017.0  Industrials             19.971161
#
#    net_profit_margin_pct  operating_profit_margin_pct  debt_to_equity  \
# 0               8.771930                    12.220206             0.0
# 1               8.699473                    11.731107             0.0
# 2              10.004369                    13.630406             0.0
# 3               9.755164                    13.963275             0.0
# 4               9.541853                    13.709955             0.0
#
#    interest_coverage  asset_turnover  free_cash_flow_cr  \
# 0                NaN        1.822492               42.0
# 1                NaN        1.998244               11.0
# 2                NaN        1.665939               28.0
# 3         138.333333        1.617574              172.0
# 4         227.500000        1.405131              152.0
#
#    dividend_payout_ratio_pct  market_cap_crore  pe_ratio  pb_ratio  \
# 0                       25.0               NaN       NaN       NaN
# 1                       25.0               NaN       NaN       NaN
# 2                       29.0               NaN       NaN       NaN
# 3                       29.0               NaN       NaN       NaN
# 4                       31.0               NaN       NaN       NaN
#
#    dividend_yield_pct   sales  net_profit compounded_sales_growth  \
# 0                 NaN  1653.0       145.0                     NaN
# 1                 NaN  2276.0       198.0                     NaN
# 2                 NaN  2289.0       229.0                     NaN
# 3                 NaN  2614.0       255.0                     NaN
# 4                 NaN  2903.0       277.0                     NaN
#
#   compounded_profit_growth
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (1200, 20)
# ['company_id', 'company_name', 'year', 'broad_sector', 'return_on_equity_pct', 'net_profit_margin_pct', 'operating_profit_margin_pct', 'debt_to_equity', 'interest_coverage', 'asset_turnover', 'free_cash_flow_cr', 'dividend_payout_ratio_pct', 'market_cap_crore', 'pe_ratio', 'pb_ratio', 'dividend_yield_pct', 'sales', 'net_profit', 'compounded_sales_growth', 'compounded_profit_growth']
