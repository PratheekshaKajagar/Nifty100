# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import importlib
import pandas as pd

import src.screener.engine as engine

importlib.reload(engine)
# Out:
# <module 'src.screener.engine' from 'c:\\Nifty100_Data_Foundation\\src\\screener\\engine.py'>

# %%
import importlib
import src.screener.engine as engine

importlib.reload(engine)

quality = engine.run_screener(
    "quality_compounder",
    DB_PATH
)

print(quality.columns.tolist())
# Out:
# ['company_id', 'company_name', 'year', 'broad_sector', 'return_on_equity_pct', 'net_profit_margin_pct', 'operating_profit_margin_pct', 'debt_to_equity', 'interest_coverage', 'asset_turnover', 'free_cash_flow_cr', 'dividend_payout_ratio_pct', 'market_cap_crore', 'pe_ratio', 'pb_ratio', 'dividend_yield_pct', 'sales', 'net_profit', 'compounded_sales_growth', 'compounded_profit_growth', 'return_on_equity_pct_score', 'net_profit_margin_pct_score', 'compounded_sales_growth_score', 'free_cash_flow_cr_score', 'debt_to_equity_score', 'composite_score']

# %%
DB_PATH = r"C:\Nifty100_Data_Foundation\data\nifty100.db"

# %%
quality = engine.run_screener(
    "quality_compounder",
    DB_PATH
)

# %%
quality[
    [
        "company_name",
        "broad_sector",
        "composite_score",
        "sector_rank",
        "sector_percentile",
        "overall_rank"
    ]
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 quality[
#       2     [
#       3         "company_name",
#       4         "broad_sector",
#
# File c:\Nifty100_Data_Foundation\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Nifty100_Data_Foundation\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
import src.screener.engine as engine

print(engine.calculate_sector_percentile)
# Out:
# <function calculate_sector_percentile at 0x0000019B193E6660>

# %%
df = engine.load_screener_data(DB_PATH)

# %%
df = engine.calculate_composite_score(df)

# %%
df.columns.tolist()
# Out:
# ['company_id',
#  'company_name',
#  'year',
#  'broad_sector',
#  'return_on_equity_pct',
#  'net_profit_margin_pct',
#  'operating_profit_margin_pct',
#  'debt_to_equity',
#  'interest_coverage',
#  'asset_turnover',
#  'free_cash_flow_cr',
#  'dividend_payout_ratio_pct',
#  'market_cap_crore',
#  'pe_ratio',
#  'pb_ratio',
#  'dividend_yield_pct',
#  'sales',
#  'net_profit',
#  'compounded_sales_growth',
#  'compounded_profit_growth',
#  'return_on_equity_pct_score',
#  'net_profit_margin_pct_score',
#  'compounded_sales_growth_score',
#  'free_cash_flow_cr_score',
#  'debt_to_equity_score',
#  'composite_score']

# %%
df = engine.calculate_sector_percentile(df)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = engine.calculate_sector_percentile(df)
#
# File c:\Nifty100_Data_Foundation\src\screener\engine.py:393, in calculate_sector_percentile(df)
#     381 ranked["sector_percentile"] = (
#     382     ranked
#     383     .groupby("broad_sector")["composite_score"]
#     384     .rank(method="average", pct=True)
#     385     * 100
#     386 )
#     388 # Sector Rank
#     389 ranked["sector_rank"] = (
#     390     ranked
#     391     .groupby("broad_sector")["composite_score"]
#     392     .rank(method="dense", ascending=False)
# --> 393     .astype(int)
#     394 )
#     396 # Overall Rank
#     397 ranked["overall_rank"] = (
#     398     ranked["composite_score"]
#     399     .rank(method="dense", ascending=False)
#     400     .astype(int)
#     401 )
#
# ...

# %%
print(df["broad_sector"].isna().sum())
print(df["composite_score"].isna().sum())
# Out:
# 0
# 86

# %%
df = engine.load_screener_data(DB_PATH)

print(df.shape)
# Out:
# (90, 20)

# %%
df = engine.calculate_composite_score(df)

print(df["composite_score"].isna().sum())
# Out:
# 86

# %%
df[df["composite_score"].isna()][
    [
        "company_name",
        "return_on_equity_pct",
        "net_profit_margin_pct",
        "compounded_sales_growth",
        "free_cash_flow_cr",
        "debt_to_equity",
        "composite_score",
    ]
]
# Out:
#                                  company_name  return_on_equity_pct  \
# 0                            Abbott India Ltd             32.468235
# 1                  Adani Energy Solutions Ltd              9.461277
# 2                       Adani Enterprises Ltd              8.534650
# 3                      Adani Green Energy Ltd             12.812691
# 4   Adani Ports & Special Economic Zone Ltd\n             15.354883
# ..                                        ...                   ...
# 85                          Tech Mahindra Ltd              8.987964
# 86                        Titan Company Ltd\n             37.219206
# 87                Torrent Pharmaceuticals Ltd             24.154026
# 88                                  Trent Ltd             36.307768
# 89                      TVS Motor Company Ltd             26.223467
#
#     net_profit_margin_pct  compounded_sales_growth  free_cash_flow_cr  \
# 0               20.533425                      NaN              797.0
# ...

# %%
print(df.dtypes)
# Out:
# company_id                           str
# company_name                         str
# year                             float64
# broad_sector                         str
# return_on_equity_pct             float64
# net_profit_margin_pct            float64
# operating_profit_margin_pct      float64
# debt_to_equity                   float64
# interest_coverage                float64
# asset_turnover                   float64
# free_cash_flow_cr                float64
# dividend_payout_ratio_pct        float64
# market_cap_crore                 float64
# pe_ratio                         float64
# pb_ratio                         float64
# dividend_yield_pct               float64
# sales                            float64
# net_profit                       float64
# compounded_sales_growth          float64
# compounded_profit_growth         float64
# return_on_equity_pct_score       float64
# net_profit_margin_pct_score      float64
# compounded_sales_growth_score    float64
# ...

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(DB_PATH)

pd.read_sql("""
SELECT company_id,
       compounded_sales_growth
FROM analysis
LIMIT 20
""", conn)
# Out:
#    company_id          compounded_sales_growth
# 0    HDFCBANK                    10 Years: 21%
# 1    HDFCBANK               5 Years:       22%
# 2    HDFCBANK               3 Years:       30%
# 3    HDFCBANK              TTM:            47%
# 4        INFY                10 Years:     12%
# 5        INFY               5 Years:       13%
# 6        INFY                3 Years:       5%
# 7        INFY               TTM:            3%
# 8     SBILIFE                10 Years:     23%
# 9     SBILIFE               5 Years:       24%
# 10    SBILIFE               3 Years:       17%
# 11    SBILIFE              TTM:            43%
# 12        TCS   10 Years:     11%
# 13        TCS  5 Years:       10%
# 14        TCS  3 Years:       14%
# 15        TCS  TTM:            5%

# %%
conn = sqlite3.connect(DB_PATH)

pd.read_sql("""
SELECT COUNT(DISTINCT company_id) AS companies
FROM analysis;
""", conn)
# Out:
#    companies
# 0          4

# %%
pd.read_sql("""
SELECT COUNT(*) AS rows
FROM analysis;
""", conn)
# Out:
#    rows
# 0    16

# %%
import pandas as pd

pd.read_sql("""
SELECT COUNT(DISTINCT company_id)
FROM financial_ratios
WHERE revenue_cagr_5yr IS NOT NULL;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Nifty100_Data_Foundation\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: revenue_cagr_5yr
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 3
#       1 import pandas as pd
#       2
# ----> 3 pd.read_sql("""
#       4 SELECT COUNT(DISTINCT company_id)
#       5 FROM financial_ratios
#       6 WHERE revenue_cagr_5yr IS NOT NULL;
#
# File c:\Nifty100_Data_Foundation\.venv\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
pd.read_sql("""
PRAGMA table_info(financial_ratios);
""", conn)
# Out:
#     cid                         name     type  notnull dflt_value  pk
# 0     0                   company_id     TEXT        0       None   0
# 1     1                         year     REAL        0       None   0
# 2     2        net_profit_margin_pct     REAL        0       None   0
# 3     3  operating_profit_margin_pct     REAL        0       None   0
# 4     4         return_on_equity_pct     REAL        0       None   0
# 5     5         return_on_assets_pct     REAL        0       None   0
# 6     6               debt_to_equity     REAL        0       None   0
# 7     7            interest_coverage     REAL        0       None   0
# 8     8               asset_turnover     REAL        0       None   0
# 9     9            free_cash_flow_cr     REAL        0       None   0
# 10   10                     capex_cr     REAL        0       None   0
# 11   11           earnings_per_share     REAL        0       None   0
# ...

# %%
df = pd.read_sql("""
SELECT *
FROM financial_ratios
LIMIT 1;
""", conn)

print(df.columns.tolist())
# Out:
# ['company_id', 'year', 'net_profit_margin_pct', 'operating_profit_margin_pct', 'return_on_equity_pct', 'return_on_assets_pct', 'debt_to_equity', 'interest_coverage', 'asset_turnover', 'free_cash_flow_cr', 'capex_cr', 'earnings_per_share', 'book_value_per_share', 'dividend_payout_ratio_pct', 'total_debt_cr', 'cash_from_operations_cr', 'composite_quality_score']

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table';
""", conn)
# Out:
#                 name
# 0          companies
# 1      profitandloss
# 2       balancesheet
# 3           cashflow
# 4           analysis
# 5          documents
# 6         market_cap
# 7        peer_groups
# 8        prosandcons
# 9            sectors
# 10      stock_prices
# 11  financial_ratios

# %%
pd.read_sql("""
PRAGMA table_info(analysis);
""", conn)
# Out:
#    cid                      name     type  notnull dflt_value  pk
# 0    0                        id  INTEGER        0       None   1
# 1    1                company_id     TEXT        1       None   0
# 2    2   compounded_sales_growth     TEXT        0       None   0
# 3    3  compounded_profit_growth     TEXT        0       None   0
# 4    4          stock_price_cagr     TEXT        0       None   0
# 5    5                       roe     TEXT        0       None   0
